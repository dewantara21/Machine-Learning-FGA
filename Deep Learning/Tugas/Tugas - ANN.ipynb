# %% [markdown]
# <img src = "https://imgur.com/s4wTnl7.jpg"  align = "center">

# %% [markdown]
# # Neural Network from Scratch

# %% [markdown]
# # 1. Pendahuluan
#
# Notebook ini merupakan latihan praktik mengimplementasikan ANN tanpa package _Deep Learning_ (seperti keras dan tensor flow). Alasan mengapa dalam notebook ini kita tidak akan menggunakan package _Deep Learning_ yang tersedia karena target dari notebook ini adalah peserta dapat mengimplementasikan beberapa persamaan yang menjadi jantung dalam algoritma ANN, seperti:
#
# 1. Implementasi _Sigmoid Function_
# 2. Implementasi perhitungan _Score dan Prediction_
# 3. Implementasi _Error Function_
# 4. Implementasi _Gradient Descent_
#
# Beberapa tahap akan dilalui untuk menyelesaikan notebook ini, antara lain:
#
# 1. Mempersiapkan perlengkapan yang akan diperlukan
# 2. Memuat dan mengenal dataset
# 3. Mempersiapkan beberapa fungsi yang akan diperlukan
# 4. Implementasi algoritma ANN (Training)
# 5. Kesimpulan

# %% [markdown]
# # 2. Mempersiapkan Perlengkapan yang Akan Diperlukan
#
# ## 2.1. Import Package
#
# Beberapa fungsi berikut merupakan fungsi dasar yang umum digunakan dalam pemrograman machine learning. Terdapat empat buah package: numpy, pandas, matplotlib, dan seaborn.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## 2.2. Fungsi Untuk Visualisasi
#
# Fungsi berikut sudah dirancang untuk memudahkan kita untuk melakukan visualisasi. Saran dari saya, kalian tidak perlu memahami fungsi ini terlalu dalam, karena fokus notebook ini bukan untuk memahami fungsi ini, melainkan konsep fundamental dari implementasi **Artificial Neural Network**. Asumsikan saja beberapa fungsi ini telah dibuat oleh orang lain yang siap dipakai dalam projek kita sekarang.

# %%
def plot_points(X, y):
    admitted = X[np.argwhere(y==1)]
    rejected = X[np.argwhere(y==0)]
    plt.scatter([s[0][0] for s in rejected], [s[0][1] for s in rejected], s = 25, color = 'blue', edgecolor = 'k')
    plt.scatter([s[0][0] for s in admitted], [s[0][1] for s in admitted], s = 25, color = 'red', edgecolor = 'k')

def display(m, b, color='g--'):
    plt.xlim(-0.05,1.05)
    plt.ylim(-0.05,1.05)
    x = np.arange(-10, 10, 0.1)
    plt.plot(x, m*x+b, color)

# %% [markdown]
# ---
# # 3. Memuat dan Mengenal Dataset
#
# Tahap ini umum dilakukan dalam pemrograman machine learning, guna memahami bagaimana rupa dataset yang kita miliki. Dalam notebook ini, dataset yang digunakan adalah berupa poin 2D yang dikelompokkan dengan dua buah label tertentu, 1 dan 0. Dataset disimpan dalam file berekstensi CSV, maka dari itu kita membutuhkan package _pandas_ untuk memuat dan melakukan eksplorasi data kita ini.

# %%
# kita load data kita
dataframe = pd.read_csv('https://raw.githubusercontent.com/dennisaprilla/UGKursus-MachineDeepLearning/master/python-ann/example_data.csv')

# periksa tipe data dari variable data
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
# lihat beberapa nilai yang paling atas
dataframe.head(10)
# Out:
#         x1        x2  y
# 0  0.78051 -0.063669  1
# 1  0.28774  0.291390  1
# 2  0.40714  0.178780  1
# 3  0.29230  0.421700  1
# 4  0.50922  0.352560  1
# 5  0.27785  0.108020  1
# 6  0.27527  0.332230  1
# 7  0.43999  0.312450  1
# 8  0.33557  0.429840  1
# 9  0.23448  0.249860  1

# %%
# tampilkan visualisasi sebaran data dalam grafik 2D
sns.scatterplot(x="x1", y="x2", data=dataframe, hue='y')

# %% [markdown]
# Untuk memudahkan operasi berikutnya, kita konversi dataframe yang kita miliki menjadi NumPy array

# %%
X = np.array(dataframe[['x1','x2']])
y = np.array(dataframe['y'])

# %% [markdown]
# ---
# # 4. Mempersiapkan Fungsi yang Diperlukan
#
# Kita membutuhkan beberapa fungsi dasar untuk mendukung proses training ANN kita. Dalam tahap ini kita akan membuat empat buah fungsi yaitu:
#
# 1. _Sigmoid Function_
# 2. _Prediction_
# 3. _Error Function_
# 4. _Gradient Descent_

# %% [markdown]
# ## 4.1. Sigmoid Activation Function
#
# **Actvation function** merupakan fungsi yang mengubah _score_ menjadi nilai tertentu yang kemudian akan diteruskan ke neuron selanjutnya. Nilai tertentu ini umumnya merupakan sebuah probabilitas yang memiliki rentang [0,1]. _Activation function_ yang akan kita gunakan disini adalah _sigmoid function_. Tentu terdapat banyak _activation function_ yang dapat digunakan (seperti softmax, reLu softmax, tanh, dll), namun pada kasus kita sekarang, kita ingin melakukan binary classification dengan probabilitas terentu, sehingga _sigmoid function_ sudah cukup untuk menangani permasalahan ini.
#
# _Sigmoid function_ didefinisikan sebagai berikut:
#
# $$\sigma(x) = \frac{1}{1+e^{-x}}$$
#
# Petunjuk spesifikasi fungsi:
# - **Input** : 1 buah; numpy array yang tiap-tiap elemnnya merupakan _score_ yang didapatkan neuron pada layer sebelumnya.
# - **Output** : 1 buah; numpy array yang tiap-tiap elemennya merupakan sebuah nilai probabilitas.

# %%
# implementasi fungsi aktivasi (sigmoid function)
def sigmoid(x):
    
    # persamaan sigmoid function
    return 1 / (1 + np.exp(-x))

# %% [markdown]
# ## 4.2. Prediction
#
# **Prediction** berupa sebuah nilai yang menunjukkan probabilitas input merupakan kelompok 1 atau kelompok 0. _Prediction_ dapat dilakukan dengan cara menghitung _score_ yang kemudian kita konversikan menjadi nilai probabilitas menggunakan fungsi _sigmoid_ yang telah kita implementasikan sebelumnya.
#
# _Prediction_  didefinisikan sebagai berikut:
#
# $$\hat{y} = \sigma(w_1 x_1 + w_2 x_2 + b)$$
#
# Petunjuk spesifikasi fungsi:
# * **Input** : 3 buah; features (x1 dan x2), weights, dan bias. Ketiganya berupa numpy array.
# * **Output** : 1 buah; numpy array yang tiap-tiap elemennya merupakan sebuah nilai prediksi.

# %%
# implementasi fungsi prediksi
def predict(features, weights, bias):
    
    # hitung score
    score = np.dot(features, weights)+bias
    
    # hitung probabilitas dan return
    return sigmoid(score)

# %% [markdown]
# ## 4.3. Error Function
#
# **Error Function** (kadang dikenal dengan _cost function_, _loss function_, _objective funtion_) merupakan sebuah fungsi yang menunjukkan seberapa buruk performa ANN kita. Semakin besar nilai _Error Function_ semakin buruk performa, dan berlaku sebaliknya. _Error function_ yang kita gunakan merupakan **Cross Entropy**, error function umum yang digunakand alam ANN dasar.
#
# _Cross Entropy_ didefinisikasn sebagai berikut:
#
# $$Error(y, \hat{y}) = - y \log(\hat{y}) - (1-y) \log(1-\hat{y})$$
#
# Petunjuk spesifikasi fungsi:
# * **Input**: 2 buah; label dan nilai prediksi. Keduanya berupa numpy array.
# * **Output**: 1 buah; numpy array yang tiap-tiap elemennya merupakan besar error tiap-tiap poin.

# %%
# implementasi error function
def error_formula(y, prediction):
    
    # persamaan cross entropy
    return -y*np.log(prediction) - (1-y)*np.log(1-prediction)

# %% [markdown]
# ## 4.4. Gradient Descent
#
# **Gradient Descent** merupakan salah satu algoritma dalam _optimisasi matematis_. Ide dari algoritma ini kita ingin melakukan update weights dan bias (yang notabene merupakan variable pembentuk ANN kita) untuk mendapatkan nilai error dari _error function_ yang terkecil. Untuk menemukan _gradien_ dalam _surface solution_ yang dibentuk oleh _error function_ adalah dengan mencari _first order derivative_ dari _error function_ itu sendiri. Penurunan _first order derivative_ dari _error function_ dapat dilihat di lampiran.
#
# Gradien descent didefinisikan sebagai berikut:
#
# $$ w_i \longrightarrow w_i + \alpha (y - \hat{y}) x_i$$

# %% [markdown]
# $$ b \longrightarrow b + \alpha (y - \hat{y})$$
#
# Petunjuk spesifikasi fungsi:
#
# * **Input**: 5 buah; Nilai input (X), label (y), prediksi (y_hat), weigths, bias, learn rate).
# * **Output**: 2 buah; Weight dan bias yang sudah di perbaharui.

# %%
# Gradient descent step
def gradient_descent(X, y, predictions, weights, bias, learnrate):
    
    # kita cari y-yhat dimasukkan kedalam delta_error menghasilkan numpy array 1D berjumlah n
    delta_error = y-predictions
    
    # kita ubah bentuk delta_error dari numpy array 1D (n) menjadi numpy array 2D (nx1)
    # alasan kita lakukan ini agar kita dapat melakukan product antara delta_error dan X
    # dimensi delta_error = (nx1) ; dimensi X = (nx2)
    delta_error = delta_error.reshape([100, 1])
    
    # update weight dan bias
    weights = weights + np.sum(learnrate * delta_error * X, axis=0)
    bias = bias + learnrate * np.sum(delta_error, axis=0)
    
    # kembalikan dua buah nilai sekaligus ke fungsi
    return weights, bias

# %% [markdown]
# # 5. Implementasi ANN (Training)
#
# Setelah kita mempersiapkan seluruhnya fungsi yang kita perlukan, saatnya kita implementasi ANN kita. Untuk merangkum teori yang telah dibahas sebelumnya, untuk melakukan training terdiri dari beberapa langkah berikut:
#
# 1. Inisialisasikan beberapa variable yang dibutuhkan oleh ANN.
# 2. Lakukan feedforward-propagation dengan _Prediction_.
# 3. Hitung besar error kita dengan _Error Function_.
# 4. Update _weights_ dan _bias_ dengan _Gradient Descent_.
# 5. Visualisasikan apa yang terjadi.
# 6. Ulangi langkah 2 sampai 5 sampai iterasi yang telah ditentukan.

# %%
# inisialisasikan beberapa variable yang dibutuhkan oleh ANN
weights = np.random.rand(2) # rand(2) w1,w2
bias = 0

# learn rate merupakan variable alpha pada persamaan gradient descent
# learnrate optimal 0.3 (loss = 0.136)
learnrate = 0.3

# epoch merupakan jumlah iterasi yang digunakan dalam melakukan gradient descent
epoch = 600

# lakukan iterasi sejumlah nilai epoch
for i in range(600):
    
    # kalkulasi prediksi (y_hat)
    predictions = predict(X, weights, bias)
    
    # hitung berapa nilai loss yang kita punya dengan melakukan mean 
    loss = np.mean(error_formula(y, predictions))
    
    # lakukan perbaharuan nilai weights dan bias menggunakan gradient descent
    weights, bias = gradient_descent(X, y, predictions, weights, bias, learnrate)
    
    # tampilkan informasi yang dibutuhkan untuk melihat apa yg sebenarnya terjadi saat proses gradient descent 
    display(-weights[0]/weights[1], -bias/weights[1])
    print('epoch = %02d, loss = %.3f, persamaan garis %.2fx + %.2fy + %.2f = 0' %
          (i, loss, weights[0], weights[0], bias) )

# tampilkan visualisasi hasil akhir
display(-weights[0]/weights[1], -bias/weights[1], 'black')
plot_points(X, y)
# Out:
# epoch = 00, loss = 0.739, persamaan garis -3.33x + -3.33y + -1.70 = 0
# epoch = 01, loss = 2.039, persamaan garis 1.88x + 1.88y + 12.93 = 0
# epoch = 02, loss = 7.655, persamaan garis -8.41x + -8.41y + -2.07 = 0
# epoch = 03, loss = 4.049, persamaan garis -3.09x + -3.09y + 12.90 = 0
# epoch = 04, loss = 4.053, persamaan garis -13.38x + -13.38y + -2.10 = 0
# epoch = 05, loss = 5.858, persamaan garis -8.05x + -8.05y + 12.89 = 0
# epoch = 06, loss = 0.753, persamaan garis -14.35x + -14.35y + 3.34 = 0
# epoch = 07, loss = 3.541, persamaan garis -9.09x + -9.09y + 17.73 = 0
# epoch = 08, loss = 2.126, persamaan garis -18.85x + -18.85y + 3.42 = 0
# epoch = 09, loss = 5.118, persamaan garis -13.55x + -13.55y + 18.03 = 0
# epoch = 10, loss = 0.317, persamaan garis -15.82x + -15.82y + 14.20 = 0
# epoch = 11, loss = 0.344, persamaan garis -14.01x + -14.01y + 18.11 = 0
# epoch = 12, loss = 0.272, persamaan garis -15.90x + -15.90y + 14.86 = 0
# epoch = 13, loss = 0.270, persamaan garis -14.44x + -14.44y + 17.91 = 0
# epoch = 14, loss = 0.212, persamaan garis -15.79x + -15.79y + 15.52 = 0
# epoch = 15, loss = 0.202, persamaan garis -14.75x + -14.75y + 17.63 = 0
# epoch = 16, loss = 0.172, persamaan garis -15.65x + -15.65y + 16.00 = 0
# epoch = 17, loss = 0.165, persamaan garis -14.94x + -14.94y + 17.40 = 0
# epoch = 18, loss = 0.153, persamaan garis -15.53x + -15.53y + 16.29 = 0
# epoch = 19, loss = 0.149, persamaan garis -15.04x + -15.04y + 17.23 = 0
# epoch = 20, loss = 0.144, persamaan garis -15.44x + -15.44y + 16.46 = 0
# epoch = 21, loss = 0.142, persamaan garis -15.10x + -15.10y + 17.11 = 0
# epoch = 22, loss = 0.140, persamaan garis -15.37x + -15.37y + 16.57 = 0
# epoch = 23, loss = 0.139, persamaan garis -15.13x + -15.13y + 17.02 = 0
# epoch = 24, loss = 0.138, persamaan garis -15.32x + -15.32y + 16.64 = 0
# epoch = 25, loss = 0.137, persamaan garis -15.14x + -15.14y + 16.96 = 0
# epoch = 26, loss = 0.137, persamaan garis -15.27x + -15.27y + 16.69 = 0
# epoch = 27, loss = 0.136, persamaan garis -15.15x + -15.15y + 16.91 = 0
# epoch = 28, loss = 0.136, persamaan garis -15.24x + -15.24y + 16.72 = 0
# epoch = 29, loss = 0.136, persamaan garis -15.14x + -15.14y + 16.88 = 0
# epoch = 30, loss = 0.136, persamaan garis -15.21x + -15.21y + 16.74 = 0
# epoch = 31, loss = 0.136, persamaan garis -15.14x + -15.14y + 16.85 = 0
# epoch = 32, loss = 0.136, persamaan garis -15.18x + -15.18y + 16.75 = 0
# epoch = 33, loss = 0.136, persamaan garis -15.13x + -15.13y + 16.83 = 0
# epoch = 34, loss = 0.136, persamaan garis -15.15x + -15.15y + 16.76 = 0
# epoch = 35, loss = 0.136, persamaan garis -15.12x + -15.12y + 16.81 = 0
# epoch = 36, loss = 0.136, persamaan garis -15.13x + -15.13y + 16.76 = 0
# epoch = 37, loss = 0.136, persamaan garis -15.10x + -15.10y + 16.80 = 0
# epoch = 38, loss = 0.136, persamaan garis -15.11x + -15.11y + 16.76 = 0
# epoch = 39, loss = 0.136, persamaan garis -15.09x + -15.09y + 16.79 = 0
# epoch = 40, loss = 0.136, persamaan garis -15.10x + -15.10y + 16.76 = 0
# epoch = 41, loss = 0.136, persamaan garis -15.08x + -15.08y + 16.78 = 0
# epoch = 42, loss = 0.136, persamaan garis -15.08x + -15.08y + 16.75 = 0
# epoch = 43, loss = 0.136, persamaan garis -15.07x + -15.07y + 16.77 = 0
# epoch = 44, loss = 0.136, persamaan garis -15.07x + -15.07y + 16.75 = 0
# epoch = 45, loss = 0.136, persamaan garis -15.05x + -15.05y + 16.76 = 0
# epoch = 46, loss = 0.136, persamaan garis -15.05x + -15.05y + 16.75 = 0
# epoch = 47, loss = 0.136, persamaan garis -15.04x + -15.04y + 16.75 = 0
# epoch = 48, loss = 0.136, persamaan garis -15.04x + -15.04y + 16.74 = 0
# epoch = 49, loss = 0.136, persamaan garis -15.03x + -15.03y + 16.74 = 0
# epoch = 50, loss = 0.136, persamaan garis -15.02x + -15.02y + 16.74 = 0
# epoch = 51, loss = 0.136, persamaan garis -15.02x + -15.02y + 16.74 = 0
# epoch = 52, loss = 0.136, persamaan garis -15.01x + -15.01y + 16.73 = 0
# epoch = 53, loss = 0.136, persamaan garis -15.00x + -15.00y + 16.73 = 0
# epoch = 54, loss = 0.136, persamaan garis -15.00x + -15.00y + 16.73 = 0
# epoch = 55, loss = 0.136, persamaan garis -14.99x + -14.99y + 16.73 = 0
# epoch = 56, loss = 0.136, persamaan garis -14.99x + -14.99y + 16.72 = 0
# epoch = 57, loss = 0.136, persamaan garis -14.98x + -14.98y + 16.72 = 0
# epoch = 58, loss = 0.136, persamaan garis -14.98x + -14.98y + 16.72 = 0
# epoch = 59, loss = 0.136, persamaan garis -14.97x + -14.97y + 16.72 = 0
# epoch = 60, loss = 0.136, persamaan garis -14.97x + -14.97y + 16.71 = 0
# epoch = 61, loss = 0.136, persamaan garis -14.96x + -14.96y + 16.71 = 0
# epoch = 62, loss = 0.136, persamaan garis -14.96x + -14.96y + 16.71 = 0
# epoch = 63, loss = 0.136, persamaan garis -14.95x + -14.95y + 16.70 = 0
# epoch = 64, loss = 0.136, persamaan garis -14.95x + -14.95y + 16.70 = 0
# epoch = 65, loss = 0.136, persamaan garis -14.94x + -14.94y + 16.70 = 0
# epoch = 66, loss = 0.136, persamaan garis -14.94x + -14.94y + 16.70 = 0
# epoch = 67, loss = 0.136, persamaan garis -14.93x + -14.93y + 16.69 = 0
# epoch = 68, loss = 0.136, persamaan garis -14.93x + -14.93y + 16.69 = 0
# epoch = 69, loss = 0.136, persamaan garis -14.92x + -14.92y + 16.69 = 0
# epoch = 70, loss = 0.136, persamaan garis -14.92x + -14.92y + 16.69 = 0
# epoch = 71, loss = 0.136, persamaan garis -14.92x + -14.92y + 16.68 = 0
# epoch = 72, loss = 0.136, persamaan garis -14.91x + -14.91y + 16.68 = 0
# epoch = 73, loss = 0.136, persamaan garis -14.91x + -14.91y + 16.68 = 0
# epoch = 74, loss = 0.136, persamaan garis -14.90x + -14.90y + 16.68 = 0
# epoch = 75, loss = 0.136, persamaan garis -14.90x + -14.90y + 16.67 = 0
# epoch = 76, loss = 0.136, persamaan garis -14.90x + -14.90y + 16.67 = 0
# epoch = 77, loss = 0.136, persamaan garis -14.89x + -14.89y + 16.67 = 0
# epoch = 78, loss = 0.136, persamaan garis -14.89x + -14.89y + 16.67 = 0
# epoch = 79, loss = 0.136, persamaan garis -14.88x + -14.88y + 16.67 = 0
# epoch = 80, loss = 0.136, persamaan garis -14.88x + -14.88y + 16.66 = 0
# epoch = 81, loss = 0.136, persamaan garis -14.88x + -14.88y + 16.66 = 0
# epoch = 82, loss = 0.136, persamaan garis -14.87x + -14.87y + 16.66 = 0
# epoch = 83, loss = 0.136, persamaan garis -14.87x + -14.87y + 16.66 = 0
# epoch = 84, loss = 0.136, persamaan garis -14.87x + -14.87y + 16.65 = 0
# epoch = 85, loss = 0.136, persamaan garis -14.86x + -14.86y + 16.65 = 0
# epoch = 86, loss = 0.136, persamaan garis -14.86x + -14.86y + 16.65 = 0
# epoch = 87, loss = 0.136, persamaan garis -14.86x + -14.86y + 16.65 = 0
# epoch = 88, loss = 0.136, persamaan garis -14.85x + -14.85y + 16.65 = 0
# epoch = 89, loss = 0.136, persamaan garis -14.85x + -14.85y + 16.64 = 0
# epoch = 90, loss = 0.136, persamaan garis -14.85x + -14.85y + 16.64 = 0
# epoch = 91, loss = 0.136, persamaan garis -14.84x + -14.84y + 16.64 = 0
# epoch = 92, loss = 0.136, persamaan garis -14.84x + -14.84y + 16.64 = 0
# epoch = 93, loss = 0.136, persamaan garis -14.84x + -14.84y + 16.64 = 0
# epoch = 94, loss = 0.136, persamaan garis -14.83x + -14.83y + 16.63 = 0
# epoch = 95, loss = 0.136, persamaan garis -14.83x + -14.83y + 16.63 = 0
# epoch = 96, loss = 0.136, persamaan garis -14.83x + -14.83y + 16.63 = 0
# epoch = 97, loss = 0.136, persamaan garis -14.83x + -14.83y + 16.63 = 0
# epoch = 98, loss = 0.136, persamaan garis -14.82x + -14.82y + 16.62 = 0
# epoch = 99, loss = 0.136, persamaan garis -14.82x + -14.82y + 16.62 = 0
# epoch = 100, loss = 0.136, persamaan garis -14.82x + -14.82y + 16.62 = 0
# epoch = 101, loss = 0.136, persamaan garis -14.81x + -14.81y + 16.62 = 0
# epoch = 102, loss = 0.136, persamaan garis -14.81x + -14.81y + 16.62 = 0
# epoch = 103, loss = 0.136, persamaan garis -14.81x + -14.81y + 16.62 = 0
# epoch = 104, loss = 0.136, persamaan garis -14.81x + -14.81y + 16.61 = 0
# epoch = 105, loss = 0.136, persamaan garis -14.80x + -14.80y + 16.61 = 0
# epoch = 106, loss = 0.136, persamaan garis -14.80x + -14.80y + 16.61 = 0
# epoch = 107, loss = 0.136, persamaan garis -14.80x + -14.80y + 16.61 = 0
# epoch = 108, loss = 0.136, persamaan garis -14.80x + -14.80y + 16.61 = 0
# epoch = 109, loss = 0.136, persamaan garis -14.79x + -14.79y + 16.60 = 0
# epoch = 110, loss = 0.136, persamaan garis -14.79x + -14.79y + 16.60 = 0
# epoch = 111, loss = 0.136, persamaan garis -14.79x + -14.79y + 16.60 = 0
# epoch = 112, loss = 0.136, persamaan garis -14.79x + -14.79y + 16.60 = 0
# epoch = 113, loss = 0.136, persamaan garis -14.79x + -14.79y + 16.60 = 0
# epoch = 114, loss = 0.136, persamaan garis -14.78x + -14.78y + 16.59 = 0
# epoch = 115, loss = 0.136, persamaan garis -14.78x + -14.78y + 16.59 = 0
# epoch = 116, loss = 0.136, persamaan garis -14.78x + -14.78y + 16.59 = 0
# epoch = 117, loss = 0.136, persamaan garis -14.78x + -14.78y + 16.59 = 0
# epoch = 118, loss = 0.136, persamaan garis -14.77x + -14.77y + 16.59 = 0
# epoch = 119, loss = 0.136, persamaan garis -14.77x + -14.77y + 16.59 = 0
# epoch = 120, loss = 0.136, persamaan garis -14.77x + -14.77y + 16.58 = 0
# epoch = 121, loss = 0.136, persamaan garis -14.77x + -14.77y + 16.58 = 0
# epoch = 122, loss = 0.136, persamaan garis -14.77x + -14.77y + 16.58 = 0
# epoch = 123, loss = 0.136, persamaan garis -14.76x + -14.76y + 16.58 = 0
# epoch = 124, loss = 0.136, persamaan garis -14.76x + -14.76y + 16.58 = 0
# epoch = 125, loss = 0.136, persamaan garis -14.76x + -14.76y + 16.58 = 0
# epoch = 126, loss = 0.136, persamaan garis -14.76x + -14.76y + 16.57 = 0
# epoch = 127, loss = 0.136, persamaan garis -14.76x + -14.76y + 16.57 = 0
# epoch = 128, loss = 0.136, persamaan garis -14.76x + -14.76y + 16.57 = 0
# epoch = 129, loss = 0.136, persamaan garis -14.75x + -14.75y + 16.57 = 0
# epoch = 130, loss = 0.136, persamaan garis -14.75x + -14.75y + 16.57 = 0
# epoch = 131, loss = 0.136, persamaan garis -14.75x + -14.75y + 16.57 = 0
# epoch = 132, loss = 0.136, persamaan garis -14.75x + -14.75y + 16.56 = 0
# epoch = 133, loss = 0.136, persamaan garis -14.75x + -14.75y + 16.56 = 0
# epoch = 134, loss = 0.136, persamaan garis -14.74x + -14.74y + 16.56 = 0
# epoch = 135, loss = 0.136, persamaan garis -14.74x + -14.74y + 16.56 = 0
# epoch = 136, loss = 0.136, persamaan garis -14.74x + -14.74y + 16.56 = 0
# epoch = 137, loss = 0.136, persamaan garis -14.74x + -14.74y + 16.56 = 0
# epoch = 138, loss = 0.136, persamaan garis -14.74x + -14.74y + 16.55 = 0
# epoch = 139, loss = 0.136, persamaan garis -14.74x + -14.74y + 16.55 = 0
# epoch = 140, loss = 0.136, persamaan garis -14.73x + -14.73y + 16.55 = 0
# epoch = 141, loss = 0.136, persamaan garis -14.73x + -14.73y + 16.55 = 0
# epoch = 142, loss = 0.136, persamaan garis -14.73x + -14.73y + 16.55 = 0
# epoch = 143, loss = 0.136, persamaan garis -14.73x + -14.73y + 16.55 = 0
# epoch = 144, loss = 0.136, persamaan garis -14.73x + -14.73y + 16.55 = 0
# epoch = 145, loss = 0.136, persamaan garis -14.73x + -14.73y + 16.54 = 0
# epoch = 146, loss = 0.136, persamaan garis -14.73x + -14.73y + 16.54 = 0
# epoch = 147, loss = 0.136, persamaan garis -14.72x + -14.72y + 16.54 = 0
# epoch = 148, loss = 0.136, persamaan garis -14.72x + -14.72y + 16.54 = 0
# epoch = 149, loss = 0.136, persamaan garis -14.72x + -14.72y + 16.54 = 0
# epoch = 150, loss = 0.136, persamaan garis -14.72x + -14.72y + 16.54 = 0
# epoch = 151, loss = 0.136, persamaan garis -14.72x + -14.72y + 16.54 = 0
# epoch = 152, loss = 0.136, persamaan garis -14.72x + -14.72y + 16.53 = 0
# epoch = 153, loss = 0.136, persamaan garis -14.71x + -14.71y + 16.53 = 0
# epoch = 154, loss = 0.136, persamaan garis -14.71x + -14.71y + 16.53 = 0
# epoch = 155, loss = 0.136, persamaan garis -14.71x + -14.71y + 16.53 = 0
# epoch = 156, loss = 0.136, persamaan garis -14.71x + -14.71y + 16.53 = 0
# epoch = 157, loss = 0.136, persamaan garis -14.71x + -14.71y + 16.53 = 0
# epoch = 158, loss = 0.136, persamaan garis -14.71x + -14.71y + 16.53 = 0
# epoch = 159, loss = 0.136, persamaan garis -14.71x + -14.71y + 16.52 = 0
# epoch = 160, loss = 0.136, persamaan garis -14.71x + -14.71y + 16.52 = 0
# epoch = 161, loss = 0.136, persamaan garis -14.70x + -14.70y + 16.52 = 0
# epoch = 162, loss = 0.136, persamaan garis -14.70x + -14.70y + 16.52 = 0
# epoch = 163, loss = 0.136, persamaan garis -14.70x + -14.70y + 16.52 = 0
# epoch = 164, loss = 0.136, persamaan garis -14.70x + -14.70y + 16.52 = 0
# epoch = 165, loss = 0.136, persamaan garis -14.70x + -14.70y + 16.52 = 0
# epoch = 166, loss = 0.136, persamaan garis -14.70x + -14.70y + 16.51 = 0
# epoch = 167, loss = 0.136, persamaan garis -14.70x + -14.70y + 16.51 = 0
# epoch = 168, loss = 0.136, persamaan garis -14.70x + -14.70y + 16.51 = 0
# epoch = 169, loss = 0.136, persamaan garis -14.69x + -14.69y + 16.51 = 0
# epoch = 170, loss = 0.136, persamaan garis -14.69x + -14.69y + 16.51 = 0
# epoch = 171, loss = 0.136, persamaan garis -14.69x + -14.69y + 16.51 = 0
# epoch = 172, loss = 0.136, persamaan garis -14.69x + -14.69y + 16.51 = 0
# epoch = 173, loss = 0.136, persamaan garis -14.69x + -14.69y + 16.51 = 0
# epoch = 174, loss = 0.136, persamaan garis -14.69x + -14.69y + 16.50 = 0
# epoch = 175, loss = 0.136, persamaan garis -14.69x + -14.69y + 16.50 = 0
# epoch = 176, loss = 0.136, persamaan garis -14.69x + -14.69y + 16.50 = 0
# epoch = 177, loss = 0.136, persamaan garis -14.69x + -14.69y + 16.50 = 0
# epoch = 178, loss = 0.136, persamaan garis -14.68x + -14.68y + 16.50 = 0
# epoch = 179, loss = 0.136, persamaan garis -14.68x + -14.68y + 16.50 = 0
# epoch = 180, loss = 0.136, persamaan garis -14.68x + -14.68y + 16.50 = 0
# epoch = 181, loss = 0.136, persamaan garis -14.68x + -14.68y + 16.50 = 0
# epoch = 182, loss = 0.136, persamaan garis -14.68x + -14.68y + 16.49 = 0
# epoch = 183, loss = 0.136, persamaan garis -14.68x + -14.68y + 16.49 = 0
# epoch = 184, loss = 0.136, persamaan garis -14.68x + -14.68y + 16.49 = 0
# epoch = 185, loss = 0.136, persamaan garis -14.68x + -14.68y + 16.49 = 0
# epoch = 186, loss = 0.136, persamaan garis -14.68x + -14.68y + 16.49 = 0
# epoch = 187, loss = 0.136, persamaan garis -14.67x + -14.67y + 16.49 = 0
# epoch = 188, loss = 0.136, persamaan garis -14.67x + -14.67y + 16.49 = 0
# epoch = 189, loss = 0.136, persamaan garis -14.67x + -14.67y + 16.49 = 0
# epoch = 190, loss = 0.136, persamaan garis -14.67x + -14.67y + 16.49 = 0
# epoch = 191, loss = 0.136, persamaan garis -14.67x + -14.67y + 16.48 = 0
# epoch = 192, loss = 0.136, persamaan garis -14.67x + -14.67y + 16.48 = 0
# epoch = 193, loss = 0.136, persamaan garis -14.67x + -14.67y + 16.48 = 0
# epoch = 194, loss = 0.136, persamaan garis -14.67x + -14.67y + 16.48 = 0
# epoch = 195, loss = 0.136, persamaan garis -14.67x + -14.67y + 16.48 = 0
# epoch = 196, loss = 0.136, persamaan garis -14.67x + -14.67y + 16.48 = 0
# epoch = 197, loss = 0.136, persamaan garis -14.66x + -14.66y + 16.48 = 0
# epoch = 198, loss = 0.136, persamaan garis -14.66x + -14.66y + 16.48 = 0
# epoch = 199, loss = 0.136, persamaan garis -14.66x + -14.66y + 16.48 = 0
# epoch = 200, loss = 0.136, persamaan garis -14.66x + -14.66y + 16.47 = 0
# epoch = 201, loss = 0.136, persamaan garis -14.66x + -14.66y + 16.47 = 0
# epoch = 202, loss = 0.136, persamaan garis -14.66x + -14.66y + 16.47 = 0
# epoch = 203, loss = 0.136, persamaan garis -14.66x + -14.66y + 16.47 = 0
# epoch = 204, loss = 0.136, persamaan garis -14.66x + -14.66y + 16.47 = 0
# epoch = 205, loss = 0.136, persamaan garis -14.66x + -14.66y + 16.47 = 0
# epoch = 206, loss = 0.136, persamaan garis -14.66x + -14.66y + 16.47 = 0
# epoch = 207, loss = 0.136, persamaan garis -14.66x + -14.66y + 16.47 = 0
# epoch = 208, loss = 0.136, persamaan garis -14.65x + -14.65y + 16.47 = 0
# epoch = 209, loss = 0.136, persamaan garis -14.65x + -14.65y + 16.46 = 0
# epoch = 210, loss = 0.136, persamaan garis -14.65x + -14.65y + 16.46 = 0
# epoch = 211, loss = 0.136, persamaan garis -14.65x + -14.65y + 16.46 = 0
# epoch = 212, loss = 0.136, persamaan garis -14.65x + -14.65y + 16.46 = 0
# epoch = 213, loss = 0.136, persamaan garis -14.65x + -14.65y + 16.46 = 0
# epoch = 214, loss = 0.136, persamaan garis -14.65x + -14.65y + 16.46 = 0
# epoch = 215, loss = 0.136, persamaan garis -14.65x + -14.65y + 16.46 = 0
# epoch = 216, loss = 0.136, persamaan garis -14.65x + -14.65y + 16.46 = 0
# epoch = 217, loss = 0.136, persamaan garis -14.65x + -14.65y + 16.46 = 0
# epoch = 218, loss = 0.136, persamaan garis -14.65x + -14.65y + 16.46 = 0
# epoch = 219, loss = 0.136, persamaan garis -14.65x + -14.65y + 16.46 = 0
# epoch = 220, loss = 0.136, persamaan garis -14.64x + -14.64y + 16.45 = 0
# epoch = 221, loss = 0.136, persamaan garis -14.64x + -14.64y + 16.45 = 0
# epoch = 222, loss = 0.136, persamaan garis -14.64x + -14.64y + 16.45 = 0
# epoch = 223, loss = 0.136, persamaan garis -14.64x + -14.64y + 16.45 = 0
# epoch = 224, loss = 0.136, persamaan garis -14.64x + -14.64y + 16.45 = 0
# epoch = 225, loss = 0.136, persamaan garis -14.64x + -14.64y + 16.45 = 0
# epoch = 226, loss = 0.136, persamaan garis -14.64x + -14.64y + 16.45 = 0
# epoch = 227, loss = 0.136, persamaan garis -14.64x + -14.64y + 16.45 = 0
# epoch = 228, loss = 0.136, persamaan garis -14.64x + -14.64y + 16.45 = 0
# epoch = 229, loss = 0.136, persamaan garis -14.64x + -14.64y + 16.45 = 0
# epoch = 230, loss = 0.136, persamaan garis -14.64x + -14.64y + 16.44 = 0
# epoch = 231, loss = 0.136, persamaan garis -14.64x + -14.64y + 16.44 = 0
# epoch = 232, loss = 0.136, persamaan garis -14.64x + -14.64y + 16.44 = 0
# epoch = 233, loss = 0.136, persamaan garis -14.63x + -14.63y + 16.44 = 0
# epoch = 234, loss = 0.136, persamaan garis -14.63x + -14.63y + 16.44 = 0
# epoch = 235, loss = 0.136, persamaan garis -14.63x + -14.63y + 16.44 = 0
# epoch = 236, loss = 0.136, persamaan garis -14.63x + -14.63y + 16.44 = 0
# epoch = 237, loss = 0.136, persamaan garis -14.63x + -14.63y + 16.44 = 0
# epoch = 238, loss = 0.136, persamaan garis -14.63x + -14.63y + 16.44 = 0
# epoch = 239, loss = 0.136, persamaan garis -14.63x + -14.63y + 16.44 = 0
# epoch = 240, loss = 0.136, persamaan garis -14.63x + -14.63y + 16.44 = 0
# epoch = 241, loss = 0.136, persamaan garis -14.63x + -14.63y + 16.43 = 0
# epoch = 242, loss = 0.136, persamaan garis -14.63x + -14.63y + 16.43 = 0
# epoch = 243, loss = 0.136, persamaan garis -14.63x + -14.63y + 16.43 = 0
# epoch = 244, loss = 0.136, persamaan garis -14.63x + -14.63y + 16.43 = 0
# epoch = 245, loss = 0.136, persamaan garis -14.63x + -14.63y + 16.43 = 0
# epoch = 246, loss = 0.136, persamaan garis -14.63x + -14.63y + 16.43 = 0
# epoch = 247, loss = 0.136, persamaan garis -14.62x + -14.62y + 16.43 = 0
# epoch = 248, loss = 0.136, persamaan garis -14.62x + -14.62y + 16.43 = 0
# epoch = 249, loss = 0.136, persamaan garis -14.62x + -14.62y + 16.43 = 0
# epoch = 250, loss = 0.136, persamaan garis -14.62x + -14.62y + 16.43 = 0
# epoch = 251, loss = 0.136, persamaan garis -14.62x + -14.62y + 16.43 = 0
# epoch = 252, loss = 0.136, persamaan garis -14.62x + -14.62y + 16.43 = 0
# epoch = 253, loss = 0.136, persamaan garis -14.62x + -14.62y + 16.43 = 0
# epoch = 254, loss = 0.136, persamaan garis -14.62x + -14.62y + 16.42 = 0
# epoch = 255, loss = 0.136, persamaan garis -14.62x + -14.62y + 16.42 = 0
# epoch = 256, loss = 0.136, persamaan garis -14.62x + -14.62y + 16.42 = 0
# epoch = 257, loss = 0.136, persamaan garis -14.62x + -14.62y + 16.42 = 0
# epoch = 258, loss = 0.136, persamaan garis -14.62x + -14.62y + 16.42 = 0
# epoch = 259, loss = 0.136, persamaan garis -14.62x + -14.62y + 16.42 = 0
# epoch = 260, loss = 0.136, persamaan garis -14.62x + -14.62y + 16.42 = 0
# epoch = 261, loss = 0.136, persamaan garis -14.62x + -14.62y + 16.42 = 0
# epoch = 262, loss = 0.136, persamaan garis -14.62x + -14.62y + 16.42 = 0
# epoch = 263, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.42 = 0
# epoch = 264, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.42 = 0
# epoch = 265, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.42 = 0
# epoch = 266, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.41 = 0
# epoch = 267, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.41 = 0
# epoch = 268, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.41 = 0
# epoch = 269, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.41 = 0
# epoch = 270, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.41 = 0
# epoch = 271, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.41 = 0
# epoch = 272, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.41 = 0
# epoch = 273, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.41 = 0
# epoch = 274, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.41 = 0
# epoch = 275, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.41 = 0
# epoch = 276, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.41 = 0
# epoch = 277, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.41 = 0
# epoch = 278, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.41 = 0
# epoch = 279, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.41 = 0
# epoch = 280, loss = 0.136, persamaan garis -14.61x + -14.61y + 16.40 = 0
# epoch = 281, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.40 = 0
# epoch = 282, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.40 = 0
# epoch = 283, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.40 = 0
# epoch = 284, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.40 = 0
# epoch = 285, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.40 = 0
# epoch = 286, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.40 = 0
# epoch = 287, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.40 = 0
# epoch = 288, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.40 = 0
# epoch = 289, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.40 = 0
# epoch = 290, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.40 = 0
# epoch = 291, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.40 = 0
# epoch = 292, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.40 = 0
# epoch = 293, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.40 = 0
# epoch = 294, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.40 = 0
# epoch = 295, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.39 = 0
# epoch = 296, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.39 = 0
# epoch = 297, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.39 = 0
# epoch = 298, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.39 = 0
# epoch = 299, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.39 = 0
# epoch = 300, loss = 0.136, persamaan garis -14.60x + -14.60y + 16.39 = 0
# epoch = 301, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.39 = 0
# epoch = 302, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.39 = 0
# epoch = 303, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.39 = 0
# epoch = 304, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.39 = 0
# epoch = 305, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.39 = 0
# epoch = 306, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.39 = 0
# epoch = 307, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.39 = 0
# epoch = 308, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.39 = 0
# epoch = 309, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.39 = 0
# epoch = 310, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.39 = 0
# epoch = 311, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.39 = 0
# epoch = 312, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.38 = 0
# epoch = 313, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.38 = 0
# epoch = 314, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.38 = 0
# epoch = 315, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.38 = 0
# epoch = 316, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.38 = 0
# epoch = 317, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.38 = 0
# epoch = 318, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.38 = 0
# epoch = 319, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.38 = 0
# epoch = 320, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.38 = 0
# epoch = 321, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.38 = 0
# epoch = 322, loss = 0.136, persamaan garis -14.59x + -14.59y + 16.38 = 0
# epoch = 323, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.38 = 0
# epoch = 324, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.38 = 0
# epoch = 325, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.38 = 0
# epoch = 326, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.38 = 0
# epoch = 327, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.38 = 0
# epoch = 328, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.38 = 0
# epoch = 329, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.38 = 0
# epoch = 330, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 331, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 332, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 333, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 334, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 335, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 336, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 337, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 338, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 339, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 340, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 341, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 342, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 343, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 344, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 345, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 346, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 347, loss = 0.136, persamaan garis -14.58x + -14.58y + 16.37 = 0
# epoch = 348, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.37 = 0
# epoch = 349, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.37 = 0
# epoch = 350, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 351, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 352, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 353, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 354, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 355, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 356, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 357, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 358, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 359, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 360, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 361, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 362, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 363, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 364, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 365, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 366, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 367, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 368, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 369, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 370, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 371, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 372, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.36 = 0
# epoch = 373, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.35 = 0
# epoch = 374, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.35 = 0
# epoch = 375, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.35 = 0
# epoch = 376, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.35 = 0
# epoch = 377, loss = 0.136, persamaan garis -14.57x + -14.57y + 16.35 = 0
# epoch = 378, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 379, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 380, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 381, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 382, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 383, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 384, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 385, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 386, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 387, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 388, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 389, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 390, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 391, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 392, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 393, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 394, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 395, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 396, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 397, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 398, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.35 = 0
# epoch = 399, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.34 = 0
# epoch = 400, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.34 = 0
# epoch = 401, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.34 = 0
# epoch = 402, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.34 = 0
# epoch = 403, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.34 = 0
# epoch = 404, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.34 = 0
# epoch = 405, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.34 = 0
# epoch = 406, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.34 = 0
# epoch = 407, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.34 = 0
# epoch = 408, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.34 = 0
# epoch = 409, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.34 = 0
# epoch = 410, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.34 = 0
# epoch = 411, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.34 = 0
# epoch = 412, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.34 = 0
# epoch = 413, loss = 0.136, persamaan garis -14.56x + -14.56y + 16.34 = 0
# epoch = 414, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.34 = 0
# epoch = 415, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.34 = 0
# epoch = 416, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.34 = 0
# epoch = 417, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.34 = 0
# epoch = 418, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.34 = 0
# epoch = 419, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.34 = 0
# epoch = 420, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.34 = 0
# epoch = 421, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.34 = 0
# epoch = 422, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.34 = 0
# epoch = 423, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.34 = 0
# epoch = 424, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.34 = 0
# epoch = 425, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.34 = 0
# epoch = 426, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.34 = 0
# epoch = 427, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.34 = 0
# epoch = 428, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.34 = 0
# epoch = 429, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 430, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 431, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 432, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 433, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 434, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 435, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 436, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 437, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 438, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 439, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 440, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 441, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 442, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 443, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 444, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 445, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 446, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 447, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 448, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 449, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 450, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 451, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 452, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 453, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 454, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 455, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 456, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 457, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 458, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 459, loss = 0.136, persamaan garis -14.55x + -14.55y + 16.33 = 0
# epoch = 460, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.33 = 0
# epoch = 461, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.33 = 0
# epoch = 462, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.33 = 0
# epoch = 463, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.33 = 0
# epoch = 464, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.33 = 0
# epoch = 465, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.33 = 0
# epoch = 466, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 467, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 468, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 469, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 470, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 471, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 472, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 473, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 474, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 475, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 476, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 477, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 478, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 479, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 480, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 481, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 482, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 483, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 484, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 485, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 486, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 487, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 488, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 489, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 490, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 491, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 492, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 493, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 494, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 495, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 496, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 497, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 498, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 499, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 500, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 501, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 502, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 503, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 504, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 505, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 506, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 507, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 508, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 509, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 510, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 511, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 512, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.32 = 0
# epoch = 513, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.31 = 0
# epoch = 514, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.31 = 0
# epoch = 515, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.31 = 0
# epoch = 516, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.31 = 0
# epoch = 517, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.31 = 0
# epoch = 518, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.31 = 0
# epoch = 519, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.31 = 0
# epoch = 520, loss = 0.136, persamaan garis -14.54x + -14.54y + 16.31 = 0
# epoch = 521, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 522, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 523, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 524, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 525, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 526, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 527, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 528, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 529, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 530, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 531, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 532, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 533, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 534, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 535, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 536, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 537, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 538, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 539, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 540, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 541, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 542, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 543, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 544, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 545, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 546, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 547, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 548, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 549, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 550, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 551, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 552, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 553, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 554, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 555, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 556, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 557, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 558, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 559, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 560, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 561, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 562, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 563, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 564, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 565, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 566, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 567, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 568, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 569, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 570, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 571, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 572, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 573, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 574, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.31 = 0
# epoch = 575, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 576, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 577, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 578, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 579, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 580, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 581, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 582, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 583, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 584, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 585, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 586, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 587, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 588, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 589, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 590, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 591, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 592, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 593, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 594, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 595, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 596, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 597, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 598, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0
# epoch = 599, loss = 0.136, persamaan garis -14.53x + -14.53y + 16.30 = 0

# %% [markdown]
# # 6. Kesimpulan
#
# Kita bisa lihat dari _snippet code_ diatas, error function kita memberikan nilai _loss_ yang semakin lama semakin kecil. Itu menunjukkan bahwa persamaan garis yang kita dapatkan semakin tepat melakukan klasifikasi poin biru dan poin merah kita.
#
# Kita juga bisa melihat performa ANN kita secara kualitatif, yakni dari visualisasi yang muncul. Garis berwarna hijau putus-putus merupakan garis batas yang diestimasikan oleh ANN. Kita dapat melihat bahwa garis tersebut berangsur-angsur memisahkan kelompok poin biru dan merah dengan baik.
#
# Pada akhirnya, dengan menggunakan ANN, kita bisa melakukan estimasi persamaan garis, yakni nilai yang tertera pada baris akhir dari output snippet diatas

# %% [markdown]
# <hr>
#
# Copyright &copy; 2019 Kursus Machine Learning dan Deep Learning [Universitas Gunadarma](https://www.gunadarma.ac.id)
